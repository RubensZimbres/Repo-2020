# %%
import datetime
import pandas as pd
from pandas_datareader import data
import numpy as np
from datetime import timedelta
#pip install pandas-datareader
import time
start=time.time()
hoje =  (datetime.datetime.today() - timedelta(days=8))      ##datetime.datetime.today()

inicio=(datetime.datetime.today() - timedelta(days=320))
data1=str(hoje.year)+'-'+str(hoje.month)+'-'+str(hoje.day)
hoje
# Out:
# datetime.datetime(2020, 11, 12, 12, 51, 11, 758998)

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Sun Nov 15 11:49:27 2020

@author: theone
"""
import datetime
import pandas as pd
from pandas_datareader import data
import numpy as np
from datetime import timedelta
#pip install pandas-datareader
import time
start=time.time()

inicio=(datetime.datetime.today() - timedelta(days=320))#.strftime("%Y,%m,%d")
      
def predict(acao):

    try:
        stock = '{}.SA'.format(acao)
        source = 'yahoo'
        
        # Set date range (Google went public August 19, 2004)
        start =inicio#datetime.datetime(2020, 3, 1)
        end = hoje
        
        # Collect Google stock data
        goog_df = data.DataReader(stock, source, start, end)
        
        dataset = goog_df['Adj Close']

        goog_df['Adj Close'].plot(kind='line', grid=True, title='{} Adjusted Closes, IPO through 2016'.format(stock))
        
        ## FIBO DINAMICO
        max_periodo=np.max(dataset[-144:])
        min_periodo=np.min(dataset[-144:])
        
        diff=max_periodo-min_periodo
        
        primeiro_fibo=min_periodo+0.328*diff
        segundo_fibo=min_periodo+0.618*diff
        meio=min_periodo+0.5*diff
        media_verde=np.mean(dataset[-15:])
        media_vermelha=np.mean(dataset[-21:])
        
        tendencia=media_verde-media_vermelha
        print(acao,tendencia)
        fibo_superior=dataset[-1]-segundo_fibo
        #limiar_superior=(max_periodo-segundo_fibo)
        #limiar_inferior=(primeiro_fibo-min_periodo)
        
        
        fibo_inferior=dataset[-1]-primeiro_fibo
        
        if tendencia>0 and fibo_inferior>0 and  dataset[-1]>dataset[-5] and dataset[-1]>primeiro_fibo:
            output='buy'
            print('buy')
        elif tendencia<0 and fibo_superior<0 and dataset[-1]<dataset[-5] and dataset[-1]<segundo_fibo:
            output='short'
            print('short')
        else:
            output='wait'
            print('wait')
        close=dataset[-1]
        ganho=(max_periodo/segundo_fibo)-1
        diferenca=media_verde-media_vermelha
        oportunidade=dataset[-1]-meio
    except Exception as e:
        print(e)
        output='NA'
        close='NA'
        ganho='NA'
        diferenca='NA'
        oportunidade='NA'
    return output, close,ganho,diferenca,oportunidade

df=pd.read_csv('Lista_Acoes_Setor.csv',sep=',',header=0)
df.columns=['Sigla','Nome_Empresa','Setor']
df['Previsao']=np.zeros(df.shape[0])
df['Close']=np.zeros(df.shape[0])
df['Potencial']=np.zeros(df.shape[0])
df['MM_diff']=np.zeros(df.shape[0])
df['eixo_xx']=np.zeros(df.shape[0])
df['Data']=np.zeros(df.shape[0])

# %%
for i in range(0,df.shape[0]):
    try:#df.shape[0]):
        df['Previsao'].iloc[i]=predict(df.iloc[i,0])[0]
        df['Close'].iloc[i]=predict(df.iloc[i,0])[1]
        df['Potencial'].iloc[i]=predict(df.iloc[i,0])[2]
        df['MM_diff'].iloc[i]=predict(df.iloc[i,0])[3]
        df['eixo_xx'].iloc[i]=predict(df.iloc[i,0])[4]
        df['Data'].iloc[i]=data1
    except:
        pass
df['Mood']=np.zeros(df.shape[0])

for i in range(0,df.shape[0]):
    if df['Previsao'][i]=='buy':
        df['Mood'][i]=1
    if df['Previsao'][i]=='short':
        df['Mood'][i]=-1
    if df['Previsao'][i]=='wait':
        df['Mood'][i]=0
    if df['Previsao'][i]=='NA':
        df['Mood'][i]=0
# Out:
# AALR3 -0.11647624969482528
# short
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# AALR3 -0.11647624969482528
# short
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# AALR3 -0.11647624969482528
# short
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# AALR3 -0.11647624969482528
# short
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# AALR3 -0.11647624969482528
# short
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# AAPL34 -0.6508572533017087
# wait
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# AAPL34 -0.6508572533017087
# wait
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# AAPL34 -0.6508572533017087
# wait
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# AAPL34 -0.6508572533017087
# wait
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# AAPL34 -0.6508572533017087
# wait
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# ABBV34 6.343428548177087
# buy
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# ABBV34 6.343428548177087
# buy
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# ABBV34 6.343428548177087
# buy
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# ABBV34 6.343428548177087
# buy
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# ABBV34 6.343428548177087
# buy
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# ABCB4 0.048952402387348215
# buy
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# ABCB4 0.048952402387348215
# buy
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# ABCB4 0.048952402387348215
# buy
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# ABCB4 0.048952402387348215
# buy
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# ABCB4 0.048952402387348215
# buy
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# ABCP11 -0.4467616489955333
# wait
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# ABCP11 -0.4467616489955333
# wait
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# ABCP11 -0.4467616489955333
# wait
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# ABCP11 -0.4467616489955333
# wait
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# ABCP11 -0.4467616489955333
# wait
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# ABEV3 0.07533333188011504
# buy
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# ABEV3 0.07533333188011504
# buy
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# ABEV3 0.07533333188011504
# buy
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# ABEV3 0.07533333188011504
# buy
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# ABEV3 0.07533333188011504
# buy
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# ABTT34 0.7658086867559462
# wait
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# ABTT34 0.7658086867559462
# wait
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# ABTT34 0.7658086867559462
# wait
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# ABTT34 0.7658086867559462
# wait
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# ABTT34 0.7658086867559462
# wait
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# ACNB34 -4.152857607886972
# wait
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# ACNB34 -4.152857607886972
# wait
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# ACNB34 -4.152857607886972
# wait
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# ACNB34 -4.152857607886972
# wait
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# ACNB34 -4.152857607886972
# wait
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# ADHM3 -0.05419048127673909
# short
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# ADHM3 -0.05419048127673909
# short
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# ADHM3 -0.05419048127673909
# short
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# ADHM3 -0.05419048127673909
# short
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# ADHM3 -0.05419048127673909
# short
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# AFLT3 -0.06866664886474538
# wait
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# AFLT3 -0.06866664886474538
# wait
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# AFLT3 -0.06866664886474538
# wait
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# AFLT3 -0.06866664886474538
# wait
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# AFLT3 -0.06866664886474538
# wait
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# AGRO3 0.20150567917596618
# buy
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# AGRO3 0.20150567917596618
# buy
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# AGRO3 0.20150567917596618
# buy
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# AGRO3 0.20150567917596618
# buy
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# AGRO3 0.20150567917596618
# buy
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# AHEB3 0.17142853509811928
# wait
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# AHEB3 0.17142853509811928
# wait
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# AHEB3 0.17142853509811928
# wait
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# AHEB3 0.17142853509811928
# wait
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# AHEB3 0.17142853509811928
# wait
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# AIGB34 6.748285784040178
# buy
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# AIGB34 6.748285784040178
# buy
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# AIGB34 6.748285784040178
# buy
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# AIGB34 6.748285784040178
# buy
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# AIGB34 6.748285784040178
# buy
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# ALMI11 -4.287620907738074
# wait
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# ALMI11 -4.287620907738074
# wait
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# ALMI11 -4.287620907738074
# wait
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# ALMI11 -4.287620907738074
# wait
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# ALMI11 -4.287620907738074
# wait
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# ALPA3 0.17047620500837013
# wait
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# ALPA3 0.17047620500837013
# wait
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# ALPA3 0.17047620500837013
# wait
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# ALPA3 0.17047620500837013
# wait
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# ALPA3 0.17047620500837013
# wait
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# ALPA4 -0.1783808026995004
# wait
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# ALPA4 -0.1783808026995004
# wait
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# ALPA4 -0.1783808026995004
# wait
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# ALPA4 -0.1783808026995004
# wait
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# ALPA4 -0.1783808026995004
# wait
# /home/rubens_zimbres_intellimetri_com_/.local/lib/python3.5/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# No data fetched for symbol ALSC3.SA using YahooDailyReader
# No data fetched for symbol ALSC3.SA using YahooDailyReader
# No data fetched for symbol ALSC3.SA using YahooDailyReader
# No data fetched for symbol ALSC3.SA using YahooDailyReader
# No data fetched for symbol ALSC3.SA using YahooDailyReader
# ALUP11 0.08923790341331639
# wait
# ALUP11 0.08923790341331639
# wait
# ALUP11 0.08923790341331639
# wait
# ALUP11 0.08923790341331639
# wait
# ALUP11 0.08923790341331639
# wait
# ALUP3 0.13876195635114463
# wait
# ALUP3 0.13876195635114463
# wait
# ALUP3 0.13876195635114463
# wait
# ALUP3 0.13876195635114463
# wait
# ALUP3 0.13876195635114463
# wait
# ALUP4 0.008952358790806692
# buy
# ALUP4 0.008952358790806692
# buy
# ALUP4 0.008952358790806692
# buy
# ALUP4 0.008952358790806692
# buy
# ALUP4 0.008952358790806692
# buy
# ALZR11 -1.4765712193080418
# wait
# ALZR11 -1.4765712193080418
# wait
# ALZR11 -1.4765712193080418
# wait
# ALZR11 -1.4765712193080418
# wait
# ALZR11 -1.4765712193080418
# wait
# AMAR3 -0.17104763757614894
# short
# AMAR3 -0.17104763757614894
# short
# AMAR3 -0.17104763757614894
# short
# AMAR3 -0.17104763757614894
# short
# AMAR3 -0.17104763757614894
# short
# AMGN34 -246.15771804082965
# wait
# AMGN34 -246.15771804082965
# wait
# AMGN34 -246.15771804082965
# wait
# AMGN34 -246.15771804082965
# wait
# AMGN34 -246.15771804082965
# wait
# AMZO34 3.573082079206202
# buy
# AMZO34 3.573082079206202
# buy
# AMZO34 3.573082079206202
# buy
# AMZO34 3.573082079206202
# buy
# AMZO34 3.573082079206202
# buy
# ANIM3 0.011904725574311215
# wait
# ANIM3 0.011904725574311215
# wait
# ANIM3 0.011904725574311215
# wait
# ANIM3 0.011904725574311215
# wait
# ANIM3 0.011904725574311215
# wait
# APER3 -0.005619049072265625
# wait
# APER3 -0.005619049072265625
# wait
# APER3 -0.005619049072265625
# wait
# APER3 -0.005619049072265625
# wait
# APER3 -0.005619049072265625
# wait
# ARMT34 0.3588567461286303
# buy
# ARMT34 0.3588567461286303
# buy
# ARMT34 0.3588567461286303
# buy
# ARMT34 0.3588567461286303
# buy
# ARMT34 0.3588567461286303
# buy
# ARNC34 3.965905180431548
# buy
# ARNC34 3.965905180431548
# buy
# ARNC34 3.965905180431548
# buy
# ARNC34 3.965905180431548
# buy
# ARNC34 3.965905180431548
# buy
# ARZZ3 2.2795701889764715
# buy
# ARZZ3 2.2795701889764715
# buy
# ARZZ3 2.2795701889764715
# buy
# ARZZ3 2.2795701889764715
# buy
# ARZZ3 2.2795701889764715
# buy
# ATOM3 -0.0250476224081857
# wait
# ATOM3 -0.0250476224081857
# wait
# ATOM3 -0.0250476224081857
# wait
# ATOM3 -0.0250476224081857
# wait
# ATOM3 -0.0250476224081857
# wait
# ATSA11 0.0
# wait
# ATSA11 0.0
# wait
# ATSA11 0.0
# wait
# ATSA11 0.0
# wait
# ATSA11 0.0
# wait
# ATTB34 0.2869528634207654
# wait
# ATTB34 0.2869528634207654
# wait
# ATTB34 0.2869528634207654
# wait
# ATTB34 0.2869528634207654
# wait
# ATTB34 0.2869528634207654
# wait
# No data fetched for symbol AVON34.SA using YahooDailyReader
# No data fetched for symbol AVON34.SA using YahooDailyReader
# No data fetched for symbol AVON34.SA using YahooDailyReader
# No data fetched for symbol AVON34.SA using YahooDailyReader
# No data fetched for symbol AVON34.SA using YahooDailyReader
# AXPB34 -5.626379394531227
# wait
# AXPB34 -5.626379394531227
# wait
# AXPB34 -5.626379394531227
# wait
# AXPB34 -5.626379394531227
# wait
# AXPB34 -5.626379394531227
# wait
# AZEV3 -0.22188631693522076
# short
# AZEV3 -0.22188631693522076
# short
# AZEV3 -0.22188631693522076
# short
# AZEV3 -0.22188631693522076
# short
# AZEV3 -0.22188631693522076
# short
# AZEV4 -0.05852820532662539
# short
# AZEV4 -0.05852820532662539
# short
# AZEV4 -0.05852820532662539
# short
# AZEV4 -0.05852820532662539
# short
# AZEV4 -0.05852820532662539
# short
# AZUL4 0.02504744756789634
# buy
# AZUL4 0.02504744756789634
# buy
# AZUL4 0.02504744756789634
# buy
# AZUL4 0.02504744756789634
# buy
# AZUL4 0.02504744756789634
# buy
# B3SA3 -0.6693335033598444
# short
# B3SA3 -0.6693335033598444
# short
# B3SA3 -0.6693335033598444
# short
# B3SA3 -0.6693335033598444
# short
# B3SA3 -0.6693335033598444
# short
# BAHI3 -5.704953293573297
# short
# BAHI3 -5.704953293573297
# short
# BAHI3 -5.704953293573297
# short
# BAHI3 -5.704953293573297
# short
# BAHI3 -5.704953293573297
# short
# BALM4 0.39409519377208824
# buy
# BALM4 0.39409519377208824
# buy
# BALM4 0.39409519377208824
# buy
# BALM4 0.39409519377208824
# buy
# BALM4 0.39409519377208824
# buy
# BAUH4 -0.5702860514322907
# wait
# BAUH4 -0.5702860514322907
# wait
# BAUH4 -0.5702860514322907
# wait
# BAUH4 -0.5702860514322907
# wait
# BAUH4 -0.5702860514322907
# wait
# BAZA3 -0.24504772367931338
# wait
# BAZA3 -0.24504772367931338
# wait
# BAZA3 -0.24504772367931338
# wait
# BAZA3 -0.24504772367931338
# wait
# BAZA3 -0.24504772367931338
# wait
# BBAS3 0.2511204492478143
# buy
# BBAS3 0.2511204492478143
# buy
# BBAS3 0.2511204492478143
# buy
# BBAS3 0.2511204492478143
# buy
# BBAS3 0.2511204492478143
# buy
# BBDC3 0.19442576453799276
# buy
# BBDC3 0.19442576453799276
# buy
# BBDC3 0.19442576453799276
# buy
# BBDC3 0.19442576453799276
# buy
# BBDC3 0.19442576453799276
# buy
# BBDC4 0.3136871701195112
# buy
# BBDC4 0.3136871701195112
# buy
# BBDC4 0.3136871701195112
# buy
# BBDC4 0.3136871701195112
# buy
# BBDC4 0.3136871701195112
# buy
# BBFI11B -50.87761579241078
# wait
# BBFI11B -50.87761579241078
# wait
# BBFI11B -50.87761579241078
# wait
# BBFI11B -50.87761579241078
# wait
# BBFI11B -50.87761579241078
# wait
# BBPO11 -0.36371445428756033
# short
# BBPO11 -0.36371445428756033
# short
# BBPO11 -0.36371445428756033
# short
# BBPO11 -0.36371445428756033
# short
# BBPO11 -0.36371445428756033
# short
# BBRC11 -0.04638076055616125
# short
# BBRC11 -0.04638076055616125
# short
# BBRC11 -0.04638076055616125
# short
# BBRC11 -0.04638076055616125
# short
# BBRC11 -0.04638076055616125
# short
# BBRK3 -0.06342857338133312
# wait
# BBRK3 -0.06342857338133312
# wait
# BBRK3 -0.06342857338133312
# wait
# BBRK3 -0.06342857338133312
# wait
# BBRK3 -0.06342857338133312
# wait
# BBSD11 -0.0208573114304329
# wait
# BBSD11 -0.0208573114304329
# wait
# BBSD11 -0.0208573114304329
# wait
# BBSD11 -0.0208573114304329
# wait
# BBSD11 -0.0208573114304329
# wait
# BBSE3 0.16876202537899943
# buy
# BBSE3 0.16876202537899943
# buy
# BBSE3 0.16876202537899943
# buy
# BBSE3 0.16876202537899943
# buy
# BBSE3 0.16876202537899943
# buy
# BBVJ11 0.07333334059942587
# wait
# BBVJ11 0.07333334059942587
# wait
# BBVJ11 0.07333334059942587
# wait
# BBVJ11 0.07333334059942587
# wait
# BBVJ11 0.07333334059942587
# wait
# BBYY34 -11.274948846726147
# wait
# BBYY34 -11.274948846726147
# wait
# BBYY34 -11.274948846726147
# wait
# BBYY34 -11.274948846726147
# wait
# BBYY34 -11.274948846726147
# wait
# BCFF11 0.0
# wait
# BCFF11 0.0
# wait
# BCFF11 0.0
# wait
# BCFF11 0.0
# wait
# BCFF11 0.0
# wait
# BCIA11 -1.0760952904110752
# short
# BCIA11 -1.0760952904110752
# short
# BCIA11 -1.0760952904110752
# short
# BCIA11 -1.0760952904110752
# short
# BCIA11 -1.0760952904110752
# short
# BCRI11 -0.034666878836503656
# wait
# BCRI11 -0.034666878836503656
# wait
# BCRI11 -0.034666878836503656
# wait
# BCRI11 -0.034666878836503656
# wait
# BCRI11 -0.034666878836503656
# wait
# BDLL4 0.10257144201369428
# wait
# BDLL4 0.10257144201369428
# wait
# BDLL4 0.10257144201369428
# wait
# BDLL4 0.10257144201369428
# wait
# BDLL4 0.10257144201369428
# wait
# BEEF3 -0.26735455649239626
# wait
# BEEF3 -0.26735455649239626
# wait
# BEEF3 -0.26735455649239626
# wait
# BEEF3 -0.26735455649239626
# wait
# BEEF3 -0.26735455649239626
# wait
# BEES3 0.019531758626301965
# wait
# BEES3 0.019531758626301965
# wait
# BEES3 0.019531758626301965
# wait
# BEES3 0.019531758626301965
# wait
# BEES3 0.019531758626301965
# wait
# BEES4 0.0469554401579364
# wait
# BEES4 0.0469554401579364
# wait
# BEES4 0.0469554401579364
# wait
# BEES4 0.0469554401579364
# wait
# BEES4 0.0469554401579364
# wait
# BERK34 2.001336960565368
# buy
# BERK34 2.001336960565368
# buy
# BERK34 2.001336960565368
# buy
# BERK34 2.001336960565368
# buy
# BERK34 2.001336960565368
# buy
# BGIP3 0.7050468808128727
# wait
# BGIP3 0.7050468808128727
# wait
# BGIP3 0.7050468808128727
# wait
# BGIP3 0.7050468808128727
# wait
# BGIP3 0.7050468808128727
# wait
# BGIP4 -0.07342861720493943
# wait
# BGIP4 -0.07342861720493943
# wait
# BGIP4 -0.07342861720493943
# wait
# BGIP4 -0.07342861720493943
# wait
# BGIP4 -0.07342861720493943
# wait
# BIDI11 -1.2593332563127788
# wait
# BIDI11 -1.2593332563127788
# wait
# BIDI11 -1.2593332563127788
# wait
# BIDI11 -1.2593332563127788
# wait
# BIDI11 -1.2593332563127788
# wait
# BIDI3 -0.32704767499651055
# wait
# BIDI3 -0.32704767499651055
# wait
# BIDI3 -0.32704767499651055
# wait
# BIDI3 -0.32704767499651055
# wait
# BIDI3 -0.32704767499651055
# wait
# BIDI4 -0.40876195998419007
# wait
# BIDI4 -0.40876195998419007
# wait
# BIDI4 -0.40876195998419007
# wait
# BIDI4 -0.40876195998419007
# wait
# BIDI4 -0.40876195998419007
# wait
# BIIB34 -1.4718084426153268
# short
# BIIB34 -1.4718084426153268
# short
# BIIB34 -1.4718084426153268
# short
# BIIB34 -1.4718084426153268
# short
# BIIB34 -1.4718084426153268
# short
# BIOM3 0.03076186407180259
# wait
# BIOM3 0.03076186407180259
# wait
# BIOM3 0.03076186407180259
# wait
# BIOM3 0.03076186407180259
# wait
# BIOM3 0.03076186407180259
# wait
# BKBR3 -0.00695241292317661
# wait
# BKBR3 -0.00695241292317661
# wait
# BKBR3 -0.00695241292317661
# wait
# BKBR3 -0.00695241292317661
# wait
# BKBR3 -0.00695241292317661
# wait
# BLAK34 -2.151904878162213
# wait
# BLAK34 -2.151904878162213
# wait
# BLAK34 -2.151904878162213
# wait
# BLAK34 -2.151904878162213
# wait
# BLAK34 -2.151904878162213
# wait
# BMEB3 -0.23342862810407183
# short
# BMEB3 -0.23342862810407183
# short
# BMEB3 -0.23342862810407183
# short
# BMEB3 -0.23342862810407183
# short
# BMEB3 -0.23342862810407183
# short
# BMEB4 -0.2800952729724706
# wait
# BMEB4 -0.2800952729724706
# wait
# BMEB4 -0.2800952729724706
# wait
# BMEB4 -0.2800952729724706
# wait
# BMEB4 -0.2800952729724706
# wait
# BMIN3 -0.21609540666852567
# wait
# BMIN3 -0.21609540666852567
# wait
# BMIN3 -0.21609540666852567
# wait
# BMIN3 -0.21609540666852567
# wait
# BMIN3 -0.21609540666852567
# wait
# BMIN4 -0.1029525030226921
# wait
# BMIN4 -0.1029525030226921
# wait
# BMIN4 -0.1029525030226921
# wait
# BMIN4 -0.1029525030226921
# wait
# BMIN4 -0.1029525030226921
# wait
# BMKS3 -0.6091430664062614
# wait
# BMKS3 -0.6091430664062614
# wait
# BMKS3 -0.6091430664062614
# wait
# BMKS3 -0.6091430664062614
# wait
# BMKS3 -0.6091430664062614
# wait
# BMLC11B -0.12304781959170441
# wait
# BMLC11B -0.12304781959170441
# wait
# BMLC11B -0.12304781959170441
# wait
# BMLC11B -0.12304781959170441
# wait
# BMLC11B -0.12304781959170441
# wait
# BMYB34 0.754669189453125
# wait
# BMYB34 0.754669189453125
# wait
# BMYB34 0.754669189453125
# wait
# BMYB34 0.754669189453125
# wait
# BMYB34 0.754669189453125
# wait
# BNBR3 -1.5283806937081579
# wait
# BNBR3 -1.5283806937081579
# wait
# BNBR3 -1.5283806937081579
# wait
# BNBR3 -1.5283806937081579
# wait
# BNBR3 -1.5283806937081579
# wait
# BNFS11 -0.14361928304036553
# short
# BNFS11 -0.14361928304036553
# short
# BNFS11 -0.14361928304036553
# short
# BNFS11 -0.14361928304036553
# short
# BNFS11 -0.14361928304036553
# short
# BOAC34 -19.22266576857794
# wait
# BOAC34 -19.22266576857794
# wait
# BOAC34 -19.22266576857794
# wait
# BOAC34 -19.22266576857794
# wait
# BOAC34 -19.22266576857794
# wait
# BOBR4 -0.01666667347862605
# wait
# BOBR4 -0.01666667347862605
# wait
# BOBR4 -0.01666667347862605
# wait
# BOBR4 -0.01666667347862605
# wait
# BOBR4 -0.01666667347862605
# wait
# BOEI34 -6.703332519531273
# wait
# BOEI34 -6.703332519531273
# wait
# BOEI34 -6.703332519531273
# wait
# BOEI34 -6.703332519531273
# wait
# BOEI34 -6.703332519531273
# wait
# BONY34 -1.7675245012555933
# wait
# BONY34 -1.7675245012555933
# wait
# BONY34 -1.7675245012555933
# wait
# BONY34 -1.7675245012555933
# wait
# BONY34 -1.7675245012555933
# wait
# BOVA11 0.16361919584728923
# buy
# BOVA11 0.16361919584728923
# buy
# BOVA11 0.16361919584728923
# buy
# BOVA11 0.16361919584728923
# buy
# BOVA11 0.16361919584728923
# buy
# BOVV11 0.1509522937592891
# buy
# BOVV11 0.1509522937592891
# buy
# BOVV11 0.1509522937592891
# buy
# BOVV11 0.1509522937592891
# buy
# BOVV11 0.1509522937592891
# buy
# BOXP34 0.17104775565011465
# buy
# BOXP34 0.17104775565011465
# buy
# BOXP34 0.17104775565011465
# buy
# BOXP34 0.17104775565011465
# buy
# BOXP34 0.17104775565011465
# buy
# BPAC11 0.3146669660295771
# buy
# BPAC11 0.3146669660295771
# buy
# BPAC11 0.3146669660295771
# buy
# BPAC11 0.3146669660295771
# buy
# BPAC11 0.3146669660295771
# buy
# BPAC3 0.5359046572730648
# buy
# BPAC3 0.5359046572730648
# buy
# BPAC3 0.5359046572730648
# buy
# BPAC3 0.5359046572730648
# buy
# BPAC3 0.5359046572730648
# buy
# BPAC5 -0.08333333333333215
# short
# BPAC5 -0.08333333333333215
# short
# BPAC5 -0.08333333333333215
# short
# BPAC5 -0.08333333333333215
# short
# BPAC5 -0.08333333333333215
# short
# BPAN4 -0.09371433258056605
# wait
# BPAN4 -0.09371433258056605
# wait
# BPAN4 -0.09371433258056605
# wait
# BPAN4 -0.09371433258056605
# wait
# BPAN4 -0.09371433258056605
# wait
# BPFF11 -0.5385716029575889
# short
# BPFF11 -0.5385716029575889
# short
# BPFF11 -0.5385716029575889
# short
# BPFF11 -0.5385716029575889
# short
# BPFF11 -0.5385716029575889
# short
# BRAP3 0.06551081339518561
# wait
# BRAP3 0.06551081339518561
# wait
# BRAP3 0.06551081339518561
# wait
# BRAP3 0.06551081339518561
# wait
# BRAP3 0.06551081339518561
# wait
# BRAP4 -0.009582846505303166
# wait
# BRAP4 -0.009582846505303166
# wait
# BRAP4 -0.009582846505303166
# wait
# BRAP4 -0.009582846505303166
# wait
# BRAP4 -0.009582846505303166
# wait
# BRAX11 0.15800061907087581
# buy
# BRAX11 0.15800061907087581
# buy
# BRAX11 0.15800061907087581
# buy
# BRAX11 0.15800061907087581
# buy
# BRAX11 0.15800061907087581
# buy
# BRCR11 -0.620476059686581
# short
# BRCR11 -0.620476059686581
# short
# BRCR11 -0.620476059686581
# short
# BRCR11 -0.620476059686581
# short
# BRCR11 -0.620476059686581
# short
# BRDT3 -0.012380945114863096
# wait
# BRDT3 -0.012380945114863096
# wait
# BRDT3 -0.012380945114863096
# wait
# BRDT3 -0.012380945114863096
# wait
# BRDT3 -0.012380945114863096
# wait
# BRFS3 -0.15171421595982082
# wait
# BRFS3 -0.15171421595982082
# wait
# BRFS3 -0.15171421595982082
# wait
# BRFS3 -0.15171421595982082
# wait
# BRFS3 -0.15171421595982082
# wait
# BRGE11 -0.029523667835054113
# wait
# BRGE11 -0.029523667835054113
# wait
# BRGE11 -0.029523667835054113
# wait
# BRGE11 -0.029523667835054113
# wait
# BRGE11 -0.029523667835054113
# wait
# BRGE12 0.023142841884067344
# buy
# BRGE12 0.023142841884067344
# buy
# BRGE12 0.023142841884067344
# buy
# BRGE12 0.023142841884067344
# buy
# BRGE12 0.023142841884067344
# buy
# BRGE3 0.2577142442975724
# buy
# BRGE3 0.2577142442975724
# buy
# BRGE3 0.2577142442975724
# buy
# BRGE3 0.2577142442975724
# buy
# BRGE3 0.2577142442975724
# buy
# BRGE6 -0.47380946931384926
# wait
# BRGE6 -0.47380946931384926
# wait
# BRGE6 -0.47380946931384926
# wait
# BRGE6 -0.47380946931384926
# wait
# BRGE6 -0.47380946931384926
# wait
# BRGE8 -0.006476247878302033
# wait
# BRGE8 -0.006476247878302033
# wait
# BRGE8 -0.006476247878302033
# wait
# BRGE8 -0.006476247878302033
# wait
# BRGE8 -0.006476247878302033
# wait
# BRIV3 0.16123813447498136
# wait
# BRIV3 0.16123813447498136
# wait
# BRIV3 0.16123813447498136
# wait
# BRIV3 0.16123813447498136
# wait
# BRIV3 0.16123813447498136
# wait
# BRIV4 0.019619087945848435
# wait
# BRIV4 0.019619087945848435
# wait
# BRIV4 0.019619087945848435
# wait
# BRIV4 0.019619087945848435
# wait
# BRIV4 0.019619087945848435
# wait
# BRKM3 0.2346665881928942
# buy
# BRKM3 0.2346665881928942
# buy
# BRKM3 0.2346665881928942
# buy
# BRKM3 0.2346665881928942
# buy
# BRKM3 0.2346665881928942
# buy
# BRKM5 0.36114267621721297
# wait
# BRKM5 0.36114267621721297
# wait
# BRKM5 0.36114267621721297
# wait
# BRKM5 0.36114267621721297
# wait
# BRKM5 0.36114267621721297
# wait
# BRML3 -0.05257143293108335
# wait
# BRML3 -0.05257143293108335
# wait
# BRML3 -0.05257143293108335
# wait
# BRML3 -0.05257143293108335
# wait
# BRML3 -0.05257143293108335
# wait
# BRPR3 -0.012761906215121854
# wait
# BRPR3 -0.012761906215121854
# wait
# BRPR3 -0.012761906215121854
# wait
# BRPR3 -0.012761906215121854
# wait
# BRPR3 -0.012761906215121854
# wait
# BRSR3 -0.036190459841774825
# short
# BRSR3 -0.036190459841774825
# short
# BRSR3 -0.036190459841774825
# short
# BRSR3 -0.036190459841774825
# short
# BRSR3 -0.036190459841774825
# short
# BRSR5 -0.04761910211472298
# wait
# BRSR5 -0.04761910211472298
# wait
# BRSR5 -0.04761910211472298
# wait
# BRSR5 -0.04761910211472298
# wait
# BRSR5 -0.04761910211472298
# wait
# BRSR6 0.059047698974609375
# wait
# BRSR6 0.059047698974609375
# wait
# BRSR6 0.059047698974609375
# wait
# BRSR6 0.059047698974609375
# wait
# BRSR6 0.059047698974609375
# wait
# BSEV3 -0.08171431223551462
# short
# BSEV3 -0.08171431223551462
# short
# BSEV3 -0.08171431223551462
# short
# BSEV3 -0.08171431223551462
# short
# BSEV3 -0.08171431223551462
# short
# ...
# wait
# GNDI3 0.6841905139741442
# wait
# GNDI3 0.6841905139741442
# wait
# GNDI3 0.6841905139741442
# wait
# GNDI3 0.6841905139741442
# wait
# GNDI3 0.6841905139741442
# wait
# GOAU3 -0.035194832938058696
# wait
# GOAU3 -0.035194832938058696
# wait
# GOAU3 -0.035194832938058696
# wait
# GOAU3 -0.035194832938058696
# wait
# GOAU3 -0.035194832938058696
# wait
# GOAU4 -0.031618908473422636
# wait
# GOAU4 -0.031618908473422636
# wait
# GOAU4 -0.031618908473422636
# wait
# GOAU4 -0.031618908473422636
# wait
# GOAU4 -0.031618908473422636
# wait
# GOGL34 -82.8570491245815
# short
# GOGL34 -82.8570491245815
# short
# GOGL34 -82.8570491245815
# short
# GOGL34 -82.8570491245815
# short
# GOGL34 -82.8570491245815
# short
# GOGL35 -83.18885614304315
# wait
# GOGL35 -83.18885614304315
# wait
# GOGL35 -83.18885614304315
# wait
# GOGL35 -83.18885614304315
# wait
# GOGL35 -83.18885614304315
# wait
# GOLL4 -0.367809513636999
# wait
# GOLL4 -0.367809513636999
# wait
# GOLL4 -0.367809513636999
# wait
# GOLL4 -0.367809513636999
# wait
# GOLL4 -0.367809513636999
# wait
# GOVE11 0.06619004749116897
# buy
# GOVE11 0.06619004749116897
# buy
# GOVE11 0.06619004749116897
# buy
# GOVE11 0.06619004749116897
# buy
# GOVE11 0.06619004749116897
# buy
# GPAR3 -0.21580946786063038
# wait
# GPAR3 -0.21580946786063038
# wait
# GPAR3 -0.21580946786063038
# wait
# GPAR3 -0.21580946786063038
# wait
# GPAR3 -0.21580946786063038
# wait
# GPCP3 0.03323807489304542
# buy
# GPCP3 0.03323807489304542
# buy
# GPCP3 0.03323807489304542
# buy
# GPCP3 0.03323807489304542
# buy
# GPCP3 0.03323807489304542
# buy
# GPIV33 -0.22714285169328985
# wait
# GPIV33 -0.22714285169328985
# wait
# GPIV33 -0.22714285169328985
# wait
# GPIV33 -0.22714285169328985
# wait
# GPIV33 -0.22714285169328985
# wait
# GRLV11 -0.1440945579892059
# wait
# GRLV11 -0.1440945579892059
# wait
# GRLV11 -0.1440945579892059
# wait
# GRLV11 -0.1440945579892059
# wait
# GRLV11 -0.1440945579892059
# wait
# GRND3 0.05483256748744303
# wait
# GRND3 0.05483256748744303
# wait
# GRND3 0.05483256748744303
# wait
# GRND3 0.05483256748744303
# wait
# GRND3 0.05483256748744303
# wait
# GSFI11 0.008285710925147516
# buy
# GSFI11 0.008285710925147516
# buy
# GSFI11 0.008285710925147516
# buy
# GSFI11 0.008285710925147516
# buy
# GSFI11 0.008285710925147516
# buy
# GSGI34 -0.5676190330868565
# wait
# GSGI34 -0.5676190330868565
# wait
# GSGI34 -0.5676190330868565
# wait
# GSGI34 -0.5676190330868565
# wait
# GSGI34 -0.5676190330868565
# wait
# GSHP3 -0.140857514880949
# short
# GSHP3 -0.140857514880949
# short
# GSHP3 -0.140857514880949
# short
# GSHP3 -0.140857514880949
# short
# GSHP3 -0.140857514880949
# short
# GTWR11 -0.2016187395368405
# wait
# GTWR11 -0.2016187395368405
# wait
# GTWR11 -0.2016187395368405
# wait
# GTWR11 -0.2016187395368405
# wait
# GTWR11 -0.2016187395368405
# wait
# GUAR3 0.07066658564976258
# wait
# GUAR3 0.07066658564976258
# wait
# GUAR3 0.07066658564976258
# wait
# GUAR3 0.07066658564976258
# wait
# GUAR3 0.07066658564976258
# wait
# HAGA3 0.016190481185913264
# wait
# HAGA3 0.016190481185913264
# wait
# HAGA3 0.016190481185913264
# wait
# HAGA3 0.016190481185913264
# wait
# HAGA3 0.016190481185913264
# wait
# HAGA4 -0.016952381815229067
# wait
# HAGA4 -0.016952381815229067
# wait
# HAGA4 -0.016952381815229067
# wait
# HAGA4 -0.016952381815229067
# wait
# HAGA4 -0.016952381815229067
# wait
# HALI34 1.9338092622302838
# buy
# HALI34 1.9338092622302838
# buy
# HALI34 1.9338092622302838
# buy
# HALI34 1.9338092622302838
# buy
# HALI34 1.9338092622302838
# buy
# HAPV3 0.5065714518229072
# wait
# HAPV3 0.5065714518229072
# wait
# HAPV3 0.5065714518229072
# wait
# HAPV3 0.5065714518229072
# wait
# HAPV3 0.5065714518229072
# wait
# HBOR3 -0.348761903671992
# short
# HBOR3 -0.348761903671992
# short
# HBOR3 -0.348761903671992
# short
# HBOR3 -0.348761903671992
# short
# HBOR3 -0.348761903671992
# short
# HBTS5 -0.01180952162969362
# short
# HBTS5 -0.01180952162969362
# short
# HBTS5 -0.01180952162969362
# short
# HBTS5 -0.01180952162969362
# short
# HBTS5 -0.01180952162969362
# short
# 'Date'
# 'Date'
# 'Date'
# 'Date'
# 'Date'
# HCRI11 0.0
# wait
# HCRI11 0.0
# wait
# HCRI11 0.0
# wait
# HCRI11 0.0
# wait
# HCRI11 0.0
# wait
# HCTR11 2.057143293108254
# wait
# HCTR11 2.057143293108254
# wait
# HCTR11 2.057143293108254
# wait
# HCTR11 2.057143293108254
# wait
# HCTR11 2.057143293108254
# wait
# HETA4 -0.0480952172052298
# short
# HETA4 -0.0480952172052298
# short
# HETA4 -0.0480952172052298
# short
# HETA4 -0.0480952172052298
# short
# HETA4 -0.0480952172052298
# short
# HFOF11 -0.2847619919549942
# wait
# HFOF11 -0.2847619919549942
# wait
# HFOF11 -0.2847619919549942
# wait
# HFOF11 -0.2847619919549942
# wait
# HFOF11 -0.2847619919549942
# wait
# HGBS11 0.42409493582587743
# buy
# HGBS11 0.42409493582587743
# buy
# HGBS11 0.42409493582587743
# buy
# HGBS11 0.42409493582587743
# buy
# HGBS11 0.42409493582587743
# buy
# HGCR11 -0.2472381591796875
# wait
# HGCR11 -0.2472381591796875
# wait
# HGCR11 -0.2472381591796875
# wait
# HGCR11 -0.2472381591796875
# wait
# HGCR11 -0.2472381591796875
# wait
# HGLG11 -1.523237682524183
# wait
# HGLG11 -1.523237682524183
# wait
# HGLG11 -1.523237682524183
# wait
# HGLG11 -1.523237682524183
# wait
# HGLG11 -1.523237682524183
# wait
# HGPO11 -0.866952224004848
# short
# HGPO11 -0.866952224004848
# short
# HGPO11 -0.866952224004848
# short
# HGPO11 -0.866952224004848
# short
# HGPO11 -0.866952224004848
# short
# HGRE11 -0.041523815336688585
# wait
# HGRE11 -0.041523815336688585
# wait
# HGRE11 -0.041523815336688585
# wait
# HGRE11 -0.041523815336688585
# wait
# HGRE11 -0.041523815336688585
# wait
# HGRU11 -0.16199951171874716
# wait
# HGRU11 -0.16199951171874716
# wait
# HGRU11 -0.16199951171874716
# wait
# HGRU11 -0.16199951171874716
# wait
# HGRU11 -0.16199951171874716
# wait
# HGTX3 -0.11028574988955242
# wait
# HGTX3 -0.11028574988955242
# wait
# HGTX3 -0.11028574988955242
# wait
# HGTX3 -0.11028574988955242
# wait
# HGTX3 -0.11028574988955242
# wait
# HMOC11 -0.7661913190569294
# wait
# HMOC11 -0.7661913190569294
# wait
# HMOC11 -0.7661913190569294
# wait
# HMOC11 -0.7661913190569294
# wait
# HMOC11 -0.7661913190569294
# wait
# HOME34 -214.3270463489351
# short
# HOME34 -214.3270463489351
# short
# HOME34 -214.3270463489351
# short
# HOME34 -214.3270463489351
# short
# HOME34 -214.3270463489351
# short
# HONB34 26.94155970982149
# buy
# HONB34 26.94155970982149
# buy
# HONB34 26.94155970982149
# buy
# HONB34 26.94155970982149
# buy
# HONB34 26.94155970982149
# buy
# HOOT4 -0.004000005267915441
# wait
# HOOT4 -0.004000005267915441
# wait
# HOOT4 -0.004000005267915441
# wait
# HOOT4 -0.004000005267915441
# wait
# HOOT4 -0.004000005267915441
# wait
# HPQB34 -1.331618390764504
# wait
# HPQB34 -1.331618390764504
# wait
# HPQB34 -1.331618390764504
# wait
# HPQB34 -1.331618390764504
# wait
# HPQB34 -1.331618390764504
# wait
# HSHY34 -0.39628542945499134
# wait
# HSHY34 -0.39628542945499134
# wait
# HSHY34 -0.39628542945499134
# wait
# HSHY34 -0.39628542945499134
# wait
# HSHY34 -0.39628542945499134
# wait
# HTMX11 -1.306666637602305
# wait
# HTMX11 -1.306666637602305
# wait
# HTMX11 -1.306666637602305
# wait
# HTMX11 -1.306666637602305
# wait
# HTMX11 -1.306666637602305
# wait
# HUSC11 -0.6207624162946388
# short
# HUSC11 -0.6207624162946388
# short
# HUSC11 -0.6207624162946388
# short
# HUSC11 -0.6207624162946388
# short
# HUSC11 -0.6207624162946388
# short
# HYPE3 -0.1676682790120445
# short
# HYPE3 -0.1676682790120445
# short
# HYPE3 -0.1676682790120445
# short
# HYPE3 -0.1676682790120445
# short
# HYPE3 -0.1676682790120445
# short
# IBMB34 -15.081239536830367
# wait
# IBMB34 -15.081239536830367
# wait
# IBMB34 -15.081239536830367
# wait
# IBMB34 -15.081239536830367
# wait
# IBMB34 -15.081239536830367
# wait
# 'Date'
# 'Date'
# 'Date'
# 'Date'
# 'Date'
# IDNT3 -0.1474285761515306
# wait
# IDNT3 -0.1474285761515306
# wait
# IDNT3 -0.1474285761515306
# wait
# IDNT3 -0.1474285761515306
# wait
# IDNT3 -0.1474285761515306
# wait
# IDVL3 0.010952388672601732
# buy
# IDVL3 0.010952388672601732
# buy
# IDVL3 0.010952388672601732
# buy
# IDVL3 0.010952388672601732
# buy
# IDVL3 0.010952388672601732
# buy
# IDVL4 0.0066666875566756545
# wait
# IDVL4 0.0066666875566756545
# wait
# IDVL4 0.0066666875566756545
# wait
# IDVL4 0.0066666875566756545
# wait
# IDVL4 0.0066666875566756545
# wait
# IGBR3 0.5591428802126934
# buy
# IGBR3 0.5591428802126934
# buy
# IGBR3 0.5591428802126934
# buy
# IGBR3 0.5591428802126934
# buy
# IGBR3 0.5591428802126934
# buy
# IGTA3 0.1005714053199398
# buy
# IGTA3 0.1005714053199398
# buy
# IGTA3 0.1005714053199398
# buy
# IGTA3 0.1005714053199398
# buy
# IGTA3 0.1005714053199398
# buy
# INEP3 0.06447619029453833
# buy
# INEP3 0.06447619029453833
# buy
# INEP3 0.06447619029453833
# buy
# INEP3 0.06447619029453833
# buy
# INEP3 0.06447619029453833
# buy
# INEP4 0.03285711379278311
# buy
# INEP4 0.03285711379278311
# buy
# INEP4 0.03285711379278311
# buy
# INEP4 0.03285711379278311
# buy
# INEP4 0.03285711379278311
# buy
# IRBR3 -0.1498095149085632
# short
# IRBR3 -0.1498095149085632
# short
# IRBR3 -0.1498095149085632
# short
# IRBR3 -0.1498095149085632
# short
# IRBR3 -0.1498095149085632
# short
# IRDM11 -0.14076218377975636
# wait
# IRDM11 -0.14076218377975636
# wait
# IRDM11 -0.14076218377975636
# wait
# IRDM11 -0.14076218377975636
# wait
# IRDM11 -0.14076218377975636
# wait
# ISUS11 -0.02314278738839448
# wait
# ISUS11 -0.02314278738839448
# wait
# ISUS11 -0.02314278738839448
# wait
# ISUS11 -0.02314278738839448
# wait
# ISUS11 -0.02314278738839448
# wait
# ITLC34 -52.655400884719114
# wait
# ITLC34 -52.655400884719114
# wait
# ITLC34 -52.655400884719114
# wait
# ITLC34 -52.655400884719114
# wait
# ITLC34 -52.655400884719114
# wait
# ITSA3 0.07961904434930744
# buy
# ITSA3 0.07961904434930744
# buy
# ITSA3 0.07961904434930744
# buy
# ITSA3 0.07961904434930744
# buy
# ITSA3 0.07961904434930744
# buy
# ITSA4 0.14428573790050692
# buy
# ITSA4 0.14428573790050692
# buy
# ITSA4 0.14428573790050692
# buy
# ITSA4 0.14428573790050692
# buy
# ITSA4 0.14428573790050692
# buy
# ITUB3 0.44138270786830347
# buy
# ITUB3 0.44138270786830347
# buy
# ITUB3 0.44138270786830347
# buy
# ITUB3 0.44138270786830347
# buy
# ITUB3 0.44138270786830347
# buy
# ITUB4 0.5772767384847022
# buy
# ITUB4 0.5772767384847022
# buy
# ITUB4 0.5772767384847022
# buy
# ITUB4 0.5772767384847022
# buy
# ITUB4 0.5772767384847022
# buy
# IVVB11 0.0
# wait
# IVVB11 0.0
# wait
# IVVB11 0.0
# wait
# IVVB11 0.0
# wait
# IVVB11 0.0
# wait
# No data fetched for symbol JBDU11.SA using YahooDailyReader
# No data fetched for symbol JBDU11.SA using YahooDailyReader
# No data fetched for symbol JBDU11.SA using YahooDailyReader
# No data fetched for symbol JBDU11.SA using YahooDailyReader
# No data fetched for symbol JBDU11.SA using YahooDailyReader
# No data fetched for symbol JBDU12.SA using YahooDailyReader
# No data fetched for symbol JBDU12.SA using YahooDailyReader
# No data fetched for symbol JBDU12.SA using YahooDailyReader
# No data fetched for symbol JBDU12.SA using YahooDailyReader
# No data fetched for symbol JBDU12.SA using YahooDailyReader
# JBDU3 0.16466665495009636
# wait
# JBDU3 0.16466665495009636
# wait
# JBDU3 0.16466665495009636
# wait
# JBDU3 0.16466665495009636
# wait
# JBDU3 0.16466665495009636
# wait
# JBDU4 0.03847618103027339
# wait
# JBDU4 0.03847618103027339
# wait
# JBDU4 0.03847618103027339
# wait
# JBDU4 0.03847618103027339
# wait
# JBDU4 0.03847618103027339
# wait
# JBSS3 -0.5452380770728702
# wait
# JBSS3 -0.5452380770728702
# wait
# JBSS3 -0.5452380770728702
# wait
# JBSS3 -0.5452380770728702
# wait
# JBSS3 -0.5452380770728702
# wait
# JFEN3 0.0
# wait
# JFEN3 0.0
# wait
# JFEN3 0.0
# wait
# JFEN3 0.0
# wait
# JFEN3 0.0
# wait
# JHSF3 -0.16438096818469816
# short
# JHSF3 -0.16438096818469816
# short
# JHSF3 -0.16438096818469816
# short
# JHSF3 -0.16438096818469816
# short
# JHSF3 -0.16438096818469816
# short
# JNJB34 -6.382854933965859
# wait
# JNJB34 -6.382854933965859
# wait
# JNJB34 -6.382854933965859
# wait
# JNJB34 -6.382854933965859
# wait
# JNJB34 -6.382854933965859
# wait
# JOPA3 0.873333231608072
# wait
# JOPA3 0.873333231608072
# wait
# JOPA3 0.873333231608072
# wait
# JOPA3 0.873333231608072
# wait
# JOPA3 0.873333231608072
# wait
# JOPA4 0.0
# wait
# JOPA4 0.0
# wait
# JOPA4 0.0
# wait
# JOPA4 0.0
# wait
# JOPA4 0.0
# wait
# JPMC34 -64.52190508161272
# wait
# JPMC34 -64.52190508161272
# wait
# JPMC34 -64.52190508161272
# wait
# JPMC34 -64.52190508161272
# wait
# JPMC34 -64.52190508161272
# wait
# JPSA3 -0.009333419799801845
# wait
# JPSA3 -0.009333419799801845
# wait
# JPSA3 -0.009333419799801845
# wait
# JPSA3 -0.009333419799801845
# wait
# JPSA3 -0.009333419799801845
# wait
# JRDM11 0.0
# wait
# JRDM11 0.0
# wait
# JRDM11 0.0
# wait
# JRDM11 0.0
# wait
# JRDM11 0.0
# wait
# JSLG3 -0.07809506370907471
# wait
# JSLG3 -0.07809506370907471
# wait
# JSLG3 -0.07809506370907471
# wait
# JSLG3 -0.07809506370907471
# wait
# JSLG3 -0.07809506370907471
# wait
# JSRE11 -0.4828573317754916
# short
# JSRE11 -0.4828573317754916
# short
# JSRE11 -0.4828573317754916
# short
# JSRE11 -0.4828573317754916
# short
# JSRE11 -0.4828573317754916
# short
# KEPL3 0.4429018656412751
# buy
# KEPL3 0.4429018656412751
# buy
# KEPL3 0.4429018656412751
# buy
# KEPL3 0.4429018656412751
# buy
# KEPL3 0.4429018656412751
# buy
# KFOF11 0.17152397519066653
# buy
# KFOF11 0.17152397519066653
# buy
# KFOF11 0.17152397519066653
# buy
# KFOF11 0.17152397519066653
# buy
# KFOF11 0.17152397519066653
# buy
# KHCB34 -1.8046657017299026
# short
# KHCB34 -1.8046657017299026
# short
# KHCB34 -1.8046657017299026
# short
# KHCB34 -1.8046657017299026
# short
# KHCB34 -1.8046657017299026
# short
# KLBN11 -0.29314286368233766
# wait
# KLBN11 -0.29314286368233766
# wait
# KLBN11 -0.29314286368233766
# wait
# KLBN11 -0.29314286368233766
# wait
# KLBN11 -0.29314286368233766
# wait
# KLBN3 -0.09085712886991981
# short
# KLBN3 -0.09085712886991981
# short
# KLBN3 -0.09085712886991981
# short
# KLBN3 -0.09085712886991981
# short
# KLBN3 -0.09085712886991981
# short
# KLBN4 -0.05219047637212881
# wait
# KLBN4 -0.05219047637212881
# wait
# KLBN4 -0.05219047637212881
# wait
# KLBN4 -0.05219047637212881
# wait
# KLBN4 -0.05219047637212881
# wait
# KMBB34 -30.351614815848166
# wait
# KMBB34 -30.351614815848166
# wait
# KMBB34 -30.351614815848166
# wait
# KMBB34 -30.351614815848166
# wait
# KMBB34 -30.351614815848166
# wait
# KNCR11 -0.21152401878720184
# wait
# KNCR11 -0.21152401878720184
# wait
# KNCR11 -0.21152401878720184
# wait
# KNCR11 -0.21152401878720184
# wait
# KNCR11 -0.21152401878720184
# wait
# KNHY11 -0.043428766159777865
# wait
# KNHY11 -0.043428766159777865
# wait
# KNHY11 -0.043428766159777865
# wait
# KNHY11 -0.043428766159777865
# wait
# KNHY11 -0.043428766159777865
# wait
# KNIP11 0.1152380080450115
# buy
# KNIP11 0.1152380080450115
# buy
# KNIP11 0.1152380080450115
# buy
# KNIP11 0.1152380080450115
# buy
# KNIP11 0.1152380080450115
# buy
# KNRE11 -0.08571427663167297
# short
# KNRE11 -0.08571427663167297
# short
# KNRE11 -0.08571427663167297
# short
# KNRE11 -0.08571427663167297
# short
# KNRE11 -0.08571427663167297
# short
# KNRI11 -2.0363820393880303
# short
# KNRI11 -2.0363820393880303
# short
# KNRI11 -2.0363820393880303
# short
# KNRI11 -2.0363820393880303
# short
# KNRI11 -2.0363820393880303
# short
# No data fetched for symbol KROT3.SA using YahooDailyReader
# No data fetched for symbol KROT3.SA using YahooDailyReader
# No data fetched for symbol KROT3.SA using YahooDailyReader
# No data fetched for symbol KROT3.SA using YahooDailyReader
# No data fetched for symbol KROT3.SA using YahooDailyReader
# LAME3 -0.6649524507068456
# short
# LAME3 -0.6649524507068456
# short
# LAME3 -0.6649524507068456
# short
# LAME3 -0.6649524507068456
# short
# LAME3 -0.6649524507068456
# short
# LAME4 -0.6787618364606587
# short
# LAME4 -0.6787618364606587
# short
# LAME4 -0.6787618364606587
# short
# LAME4 -0.6787618364606587
# short
# LAME4 -0.6787618364606587
# short
# LCAM3 0.29047611781528815
# wait
# LCAM3 0.29047611781528815
# wait
# LCAM3 0.29047611781528815
# wait
# LCAM3 0.29047611781528815
# wait
# LCAM3 0.29047611781528815
# wait
# LEVE3 0.05114270164853352
# wait
# LEVE3 0.05114270164853352
# wait
# LEVE3 0.05114270164853352
# wait
# LEVE3 0.05114270164853352
# wait
# LEVE3 0.05114270164853352
# wait
# LIGT3 0.6898095448811858
# wait
# LIGT3 0.6898095448811858
# wait
# LIGT3 0.6898095448811858
# wait
# LIGT3 0.6898095448811858
# wait
# LIGT3 0.6898095448811858
# wait
# LILY34 -7.383048793247781
# short
# LILY34 -7.383048793247781
# short
# LILY34 -7.383048793247781
# short
# LILY34 -7.383048793247781
# short
# LILY34 -7.383048793247781
# short
# LINX3 0.014095597040089558
# wait
# LINX3 0.014095597040089558
# wait
# LINX3 0.014095597040089558
# wait
# LINX3 0.014095597040089558
# wait
# LINX3 0.014095597040089558
# wait
# LIPR3 0.4138094220842561
# wait
# LIPR3 0.4138094220842561
# wait
# LIPR3 0.4138094220842561
# wait
# LIPR3 0.4138094220842561
# wait
# LIPR3 0.4138094220842561
# wait
# No data fetched for symbol LIQO3.SA using YahooDailyReader
# No data fetched for symbol LIQO3.SA using YahooDailyReader
# No data fetched for symbol LIQO3.SA using YahooDailyReader
# No data fetched for symbol LIQO3.SA using YahooDailyReader
# No data fetched for symbol LIQO3.SA using YahooDailyReader
# LLIS3 -0.14438092367989697
# wait
# LLIS3 -0.14438092367989697
# wait
# LLIS3 -0.14438092367989697
# wait
# LLIS3 -0.14438092367989697
# wait
# LLIS3 -0.14438092367989697
# wait
# LMTB34 -33.7694428943455
# wait
# LMTB34 -33.7694428943455
# wait
# LMTB34 -33.7694428943455
# wait
# LMTB34 -33.7694428943455
# wait
# LMTB34 -33.7694428943455
# wait
# LOFT11B -0.26666684831891274
# short
# LOFT11B -0.26666684831891274
# short
# LOFT11B -0.26666684831891274
# short
# LOFT11B -0.26666684831891274
# short

# %%
df.Potencial

# %%
def norm(x):
    return (x-np.min(x))/(np.max(x)-np.min(x))

for i in range(0,df.shape[0]):
    if df.Previsao[i]=='buy':
        df['Mood'][i]=1
    elif df.Previsao[i]=='short':
        df['Mood'][i]=-1
    else:
        df['Mood'][i]=0

# %%
df=df[df.Potencial!='NA']

# %%
df['Y_ForçaMM']=norm(df.Potencial)
df['X_Probabilidade_Fibo']=norm(df.eixo_xx)

# %%
df.columns

# %%
df[['Sigla', 'Nome_Empresa', 'Previsao', 'Close', 'Potencial', 'MM_diff',
       'eixo_xx', 'Mood', 'Y_ForçaMM', 'X_Probabilidade_Fibo','Data','Setor']].to_csv('dataframe_PowerBI.csv',sep=',',index=False,columns=df.columns)

# %%
import datetime

import pandas as pd
import pytz
import numpy as np
# Construct a BigQuery client object.

# TODO(developer): Set table_id to the ID of the table to create.
# table_id = "your-project.your_dataset.your_table_name"


dataframe = pd.read_csv('dataframe_PowerBI.csv',sep=',',header=0)

dataframe=dataframe.dropna(axis=0)
dataframe
dataframe['Data'] = dataframe['Data'].astype('datetime64[ns]')
dataframe.columns=['Sigla', 'Nome_Empresa', 'Setor','Previsao', 'Close', 'Potencial', 'MM_diff',
       'eixo_xx', 'Data', 'Mood', 'Y_For__aMM', 'X_Probabilidade_Fibo']
dataframe=dataframe[['Sigla', 'Nome_Empresa', 'Previsao', 'Close', 'Potencial', 'MM_diff',
       'eixo_xx',  'Mood', 'Y_For__aMM', 'X_Probabilidade_Fibo','Data','Setor']]
dataframe

# %%
from google.cloud import bigquery
client = bigquery.Client()

job_config = bigquery.LoadJobConfig(
    # Specify a (partial) schema. All columns are always written to the
    # table. The schema is used to assist in data type definitions.
    schema=[
        # Specify the type of columns whose type cannot be auto-detected. For
        # example the "title" column uses pandas dtype "object", so its
        # data type is ambiguous.
        bigquery.SchemaField("Sigla", bigquery.enums.SqlTypeNames.STRING),
        # Indexes are written if included in the schema by name.
        bigquery.SchemaField("Nome_Empresa", bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField("Previsao", bigquery.enums.SqlTypeNames.STRING),
        bigquery.SchemaField("Close", bigquery.enums.SqlTypeNames.FLOAT),
        bigquery.SchemaField("Potencial", bigquery.enums.SqlTypeNames.FLOAT),
        bigquery.SchemaField("MM_diff", bigquery.enums.SqlTypeNames.FLOAT),
        bigquery.SchemaField("eixo_xx", bigquery.enums.SqlTypeNames.FLOAT),
        bigquery.SchemaField("Mood", bigquery.enums.SqlTypeNames.INTEGER),
        bigquery.SchemaField("Y_For__aMM", bigquery.enums.SqlTypeNames.FLOAT),
        bigquery.SchemaField("X_Probabilidade_Fibo", bigquery.enums.SqlTypeNames.FLOAT),
        bigquery.SchemaField("Data", bigquery.enums.SqlTypeNames.DATE),
        bigquery.SchemaField("Setor", bigquery.enums.SqlTypeNames.STRING),
    ],
    # Optionally, set the write disposition. BigQuery appends loaded rows
    # to an existing table by default, but with WRITE_TRUNCATE write
    # disposition it replaces the table with the loaded data.
    write_disposition="WRITE_APPEND",
)

job = client.load_table_from_dataframe(
    dataframe, 'machinelearning.dataset.table', job_config=job_config
)  # Make an API request.
job.result()  # Wait for the job to complete.
